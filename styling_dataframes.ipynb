# %%
#https://www.kaggle.com/nxrprime/styling-data-frames-covid-19-vs-conferences

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Interactivity

# %%
# Interactivity
def magnify():
    return [dict(selector="th",
                 props=[("font-size", "9pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '300px'),
                        ('font-size', '15pt')])
]



np.random.seed(25)
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)
bigdf = pd.DataFrame(np.random.randn(20, 25)).cumsum()

bigdf.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '2pt'})\
    .set_caption("Hover to magnify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_ccd4f64c_69de_11ea_bbeb_75ff0f746492 th {
#           font-size: 9pt;
#     }    #T_ccd4f64c_69de_11ea_bbeb_75ff0f746492 td {
#           padding: 0em 0em;
#     }    #T_ccd4f64c_69de_11ea_bbeb_75ff0f746492 th:hover {
#           font-size: 12pt;
#     }    #T_ccd4f64c_69de_11ea_bbeb_75ff0f746492 tr:hover td:hover {
#           max-width: 300px;
#           font-size: 15pt;
#     }    #T_ccd4f64c_69de_11ea_bbeb_75ff0f746492row0_col0 {
#             background-color:  #ecf2f8;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  2pt;
#         }    #T_ccd4f64c_69de_11ea_bbeb_75ff0f746492row0_col1 {
#             background-color:  #b8cce5;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  2pt;
#         }    #T_ccd4f64c_69de_11ea_bbeb_75ff0f746492row0_col2 {
#             background-color:  #efb1be;
#             color:  #000000;
#             max-width:  80px;
# ...

# %% [markdown]
# # Background gradients

# %%
df3_columns = bigdf.iloc[:,0:3].copy()
df3_columns.style.background_gradient(cmap="Greens")
# Out:
# <style  type="text/css" >
#     #T_ccdb961e_69de_11ea_bbeb_75ff0f746492row0_col0 {
#             background-color:  #9ed798;
#             color:  #000000;
#         }    #T_ccdb961e_69de_11ea_bbeb_75ff0f746492row0_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_ccdb961e_69de_11ea_bbeb_75ff0f746492row0_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_ccdb961e_69de_11ea_bbeb_75ff0f746492row1_col0 {
#             background-color:  #dbf1d5;
#             color:  #000000;
#         }    #T_ccdb961e_69de_11ea_bbeb_75ff0f746492row1_col1 {
#             background-color:  #e8f6e4;
#             color:  #000000;
#         }    #T_ccdb961e_69de_11ea_bbeb_75ff0f746492row1_col2 {
#             background-color:  #005e26;
#             color:  #f1f1f1;
#         }    #T_ccdb961e_69de_11ea_bbeb_75ff0f746492row2_col0 {
#             background-color:  #bce4b5;
#             color:  #000000;
# ...

# %% [markdown]
# # Highlight min/max

# %%
def highlight_max(s, color="pink"):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: {}'.format(color) if v else '' for v in is_max]

df3_columns.style.apply(highlight_max, subset=[0,1])
# Out:
# <style  type="text/css" >
#     #T_ccde17cc_69de_11ea_bbeb_75ff0f746492row18_col0 {
#             background-color:  pink;
#         }    #T_ccde17cc_69de_11ea_bbeb_75ff0f746492row19_col1 {
#             background-color:  pink;
#         }</style><table id="T_ccde17cc_69de_11ea_bbeb_75ff0f746492" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ccde17cc_69de_11ea_bbeb_75ff0f746492level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ccde17cc_69de_11ea_bbeb_75ff0f746492row0_col0" class="data row0 col0" >0.228273</td>
#                         <td id="T_ccde17cc_69de_11ea_bbeb_75ff0f746492row0_col1" class="data row0 col1" >1.02689</td>
# ...

# %%
def highlight_min(s, color="blanchedalmond"):
    '''
    highlight the minimum in a series blanched almond (no, I do not know what that is).
    '''
    is_max = s == s.min()
    return ['background-color: {}'.format(color) if v else '' for v in is_max]
df3_columns.style.apply(highlight_min)
# Out:
# <style  type="text/css" >
#     #T_cce16b70_69de_11ea_bbeb_75ff0f746492row0_col1 {
#             background-color:  blanchedalmond;
#         }    #T_cce16b70_69de_11ea_bbeb_75ff0f746492row4_col0 {
#             background-color:  blanchedalmond;
#         }    #T_cce16b70_69de_11ea_bbeb_75ff0f746492row9_col2 {
#             background-color:  blanchedalmond;
#         }</style><table id="T_cce16b70_69de_11ea_bbeb_75ff0f746492" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cce16b70_69de_11ea_bbeb_75ff0f746492level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cce16b70_69de_11ea_bbeb_75ff0f746492row0_col0" class="data row0 col0" >0.228273</td>
# ...
